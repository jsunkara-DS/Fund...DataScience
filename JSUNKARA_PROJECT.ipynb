# %% [markdown]
# # JASWANTH SUNKARA | JSUNKARA | FINAL PROJECT

# %% [markdown]
# ## DATA ANALYSIS AND VISUALIZATION ON VEDIOGAME SALES DATASET

# %% [markdown]
# # DESCRIPTION

# %% [markdown]
# The dataset is from https://www.kaggle.com/gregorut/videogamesales
# The dataset contains the sales information of different vediogames globally and the attributes are as follows
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.

# %%
import pandas as pd
data = pd.read_csv("vgsales.csv")
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
data.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# # Platforms

# %%
data['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# # Dropping null values

# %%
data=data.dropna()
data.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# # Central tendency and Dispersion

# %%
data.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %% [markdown]
# The average rank is 8290 where max is 16600 and std.deviation for rank is 4792.

# %%
data.skew()
# Out:
# C:\Users\jaswa\AppData\Local\Temp/ipykernel_11848/1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# Rank             0.000266
# Year            -1.003509
# NA_Sales        18.740913
# EU_Sales        18.774796
# JP_Sales        11.124214
# Other_Sales     24.102609
# Global_Sales    17.304312
# dtype: float64

# %%
data.kurtosis()
# Out:
# C:\Users\jaswa\AppData\Local\Temp/ipykernel_11848/2361870383.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.kurtosis()
# Rank              -1.200867
# Year               1.845387
# NA_Sales         642.909262
# EU_Sales         746.431300
# JP_Sales         191.209577
# Other_Sales     1011.974945
# Global_Sales     596.004589
# dtype: float64

# %% [markdown]
# # Correlation (Pearson's)

# %%
data.corr()
# Out:
#                   Rank      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank          1.000000  0.178027 -0.400315 -0.379137 -0.269323    -0.332735
# Year          0.178027  1.000000 -0.091285  0.006108 -0.169387     0.041128
# NA_Sales     -0.400315 -0.091285  1.000000  0.768923  0.451283     0.634518
# EU_Sales     -0.379137  0.006108  0.768923  1.000000  0.436379     0.726256
# JP_Sales     -0.269323 -0.169387  0.451283  0.436379  1.000000     0.290559
# Other_Sales  -0.332735  0.041128  0.634518  0.726256  0.290559     1.000000
# Global_Sales -0.426975 -0.074647  0.941269  0.903264  0.612774     0.747964
#
#               Global_Sales
# Rank             -0.426975
# Year             -0.074647
# NA_Sales          0.941269
# EU_Sales          0.903264
# JP_Sales          0.612774
# Other_Sales       0.747964
# Global_Sales      1.000000

# %% [markdown]
# * The strongest correlation of rank is with global sales and NA sales.

# %% [markdown]
# # VISUALIZATIONS

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plot
# %matplotlib inline

# %% [markdown]
# ## COUNTPLOT

# %%
plot.figure(figsize=(15,8))
sns.countplot(data = data, x='Platform')
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='count'>

# %% [markdown]
# THE above plot shows the different platforms on x-axis and their game count on y-axis
# We can see that  DS and PS2 platforms have highest number of gamnes

# %%
plot.figure(figsize=(15,8))
sns.countplot(data=data, x='Year')
plot.xticks(rotation =45);

# %% [markdown]
# The above plot shows the number of games released in different years i.e 1980-2020
# The years 2006 and 2007 has the most number of releases among all

# %%
plot.figure(figsize=(15,8))
sns.countplot(data=data, x='Genre')
plot.xticks(rotation =45);

# %% [markdown]
# The plot shows different genres and their game count
# The action genre have highest count compared to other genres

# %% [markdown]
# # Barplot

# %%
sns.barplot(data=data, x='Global_Sales', y='Genre')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Genre'>

# %%
sns.pairplot(data)

# %% [markdown]
# # HEATMAP

# %%
plot.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot=True)
plot.show()

# %% [markdown]
# # HISTOGRAM

# %%
data['Year'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # GRAPHPLOTS

# %%
ax=plot.figure(figsize=(15,6))
data.groupby(['Year'])['Global_Sales'].sum().plot()
plot.grid()
plot.ylabel('Global Sales')
plot.title('Global Sales over the years')
# Out:
# Text(0.5, 1.0, 'Global Sales over the years')

# %%
GSales_Year = data.groupby('Year')[['Global_Sales','NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()
GSales_Year.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # TRAINING MODEL

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import LabelEncoder

data1 = data.copy()

le = LabelEncoder()

feature = ["Platform", "Genre"]


for col in feature:
    data1[col] = le.fit_transform(data[col])

# %%
data1.head()
# Out:
#    Rank                      Name  Platform    Year  Genre Publisher  \
# 0     1                Wii Sports        26  2006.0     10  Nintendo
# 1     2         Super Mario Bros.        11  1985.0      4  Nintendo
# 2     3            Mario Kart Wii        26  2008.0      6  Nintendo
# 3     4         Wii Sports Resort        26  2009.0     10  Nintendo
# 4     5  Pokemon Red/Pokemon Blue         5  1996.0      7  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
X = data1[['Platform', 'Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].values

y = data1['Global_Sales'].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import RobustScaler
ro = RobustScaler()
x_train = ro.fit_transform(x_train)
x_test = ro.fit_transform(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score,classification_report, roc_curve

# %%
regressor = DecisionTreeRegressor()
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
regressor.score(x_train,y_train)
# Out:
# 0.9999978583167408

# %%
regressor.score(x_test,y_test)
# Out:
# 0.8150850471910797

# %%
yTreePre= regressor.predict(x_test)

# %%
r2Tree= r2_score(y_test ,yTreePre )
r2Tree
# Out:
# 0.8150850471910797

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(yTreePre, y_test)
print('Mean absolute error '+str(mae))
# Out:
# Mean absolute error 0.06009013393183861

# %%
db = pd.DataFrame({'Actual': y_test, 'Predicted': yTreePre})
db
# Out:
#       Actual  Predicted
# 0       0.57   0.580000
# 1       0.07   0.040000
# 2       0.19   0.190000
# 3       0.67   0.650000
# 4       0.22   0.220000
# ...      ...        ...
# 4068    0.05   0.043333
# 4069    0.06   0.050000
# 4070    2.20   2.170000
# 4071    0.06   0.070000
# 4072    0.13   0.130000
#
# [4073 rows x 2 columns]

# %%
db1 = db.head()
db1.plot(kind='line',figsize=(15,8))
plot.show()

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.999986958373658

# %%
lr.score(x_test,y_test)
# Out:
# 0.9999921933389818

# %%
yLinearPre = lr.predict(x_test)

# %%
r2Linear = r2_score(y_test , yLinearPre)
r2Linear
# Out:
# 0.9999921933389818

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(yLinearPre, y_test)
print('Mean absolute error '+str(mae))
# Out:
# Mean absolute error 0.003023366562357878

# %%
dbLinear = pd.DataFrame({'Actual': y_test, 'Predicted': yLinearPre})
dbLinear
# Out:
#       Actual  Predicted
# 0       0.57   0.570374
# 1       0.07   0.060217
# 2       0.19   0.190317
# 3       0.67   0.670245
# 4       0.22   0.220396
# ...      ...        ...
# 4068    0.05   0.040179
# 4069    0.06   0.050394
# 4070    2.20   2.189877
# 4071    0.06   0.060322
# 4072    0.13   0.130427
#
# [4073 rows x 2 columns]

# %%
dbLinear1 = dbLinear.head()
dbLinear1.plot(kind='line',figsize=(15,8))
plot.show()

# %% [markdown]
# # LINEAR REGRESSION MODEL PERFORMS BETTER THAN DECISIONTREE MODEL.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# * Most Games produced in Specific Gaming Platform is DS then Ps2
# * The most popular type of game is Action then Sports. Lowest is Puzzle
# * Top 10 Publisher in order and most is Electronic Arts
# * Most games Produced in between 2002 to 2016 sp in 2010
# * Most published type of games is Action
# * Most of sales between 2005 and 2010 .lest sales in 1980 to 1990
